# %% [markdown]
# # Multiple linear Regression
# - More than two variables
# - One dependent and more than one independent
#   1. Features:

# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# import your data
df = pd.read_csv("unconv_MV_v5.csv")

df.head()
# Out:
#    Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0     1  12.08  2.92  2.80    81.40  1.16  2.31  4165.196191
# 1     2  12.38  3.53  3.22    46.17  0.89  1.88  3561.146205
# 2     3  14.02  2.59  4.01    72.80  0.89  2.72  4284.348574
# 3     4  17.67  6.75  2.63    39.81  1.08  1.88  5098.680869
# 4     5  17.52  4.57  3.18    10.94  1.51  1.90  3406.132832

# %%
X = df[['Por', 'Perm', 'AI']]
y = df['Prod']

# %%
# create and fit the model
model = LinearRegression().fit(X, y)
model
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([240.95837926, 100.152191  , -27.76873917])

# %%
model.intercept_
# Out:
# 347.6837648940045

# %%
# predict the model
model.predict([[12.08, 2.92, 2.80]])
# Out:
# c:\Users\Sheharyar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3473.15291447])

# %%
# How to plot multiple linear regression
# How to test the Efficacy of the model
# How to check the regression score of the model

# %%
# split data for training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.2, random_state=5)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (160,)
# (40, 3)
# (40,)

# %%
# linear regression model for training
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(X_train, y_train)
model
# Out:
# LinearRegression()

# %% [markdown]
# # Predict the test results
# ## Use the predict method to predict the results, then pass the independent variables into it and view the results, it will give the array with all values in it.

# %%
y_pred = model.predict(X_test)
y_pred_train = model.predict(X_train)
y_pred_train.shape
# Out:
# (160,)

# %% [markdown]
# # Evaluate the Model
# ## We have different metrics to find the accuracy score of the model and here we use r2_score to evaluate our model and find its accuracy.

# %%
# import library for r2 value calculation
from sklearn.metrics import r2_score
accuracy = r2_score(y_test, y_pred)*100
accuracy1 = r2_score(y_train, y_pred_train)*100
print("Accuracy of the test model is %.2f", accuracy)
print("Accuracy of the train model is %.2f", accuracy1)
# Out:
# Accuracy of the test model is %.2f 79.35673703305474
# Accuracy of the train model is %.2f 74.4347979770485

# %% [markdown]
# # Plot the results
# ## We will plot the scatter plot between the actual values and predicted values

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred);
plt.xlabel("Actual");
plt.ylabel("Predicted");

# %% [markdown]
# # Regression plot of our model
# A regression plot is useful to understand the relationship between two parameters. it creates a regression line in between those parameters\
# and then plot a scatter plot of those data points.

# %%
import seaborn as sns
sns.regplot(x= y_test, y= y_pred, ci=None, color= 'blue')
# Out:
# <AxesSubplot: xlabel='Prod'>

# %% [markdown]
# # Assignment is how to plot multiple linear regression model?
# # How to test the efficacy of model?

# %% [markdown]
# # Predicted values
# let us create a new data frame that contains actual value, predicted value and their difference\
# so that we understand how near the model predicts its actual value

# %%
pred_df = pd.DataFrame({'Actual value':y_test, 'Predicted value':y_pred, "Difference":y_test-y_pred})
pred_df
# Out:
#      Actual value  Predicted value   Difference
# 119   5568.129512      5135.768174   432.361338
# 77    3190.699612      2960.169068   230.530544
# 148   3950.292582      3953.644177    -3.351595
# 149   3418.470532      4474.314083 -1055.843551
# 154   3341.157722      4385.800355 -1044.642633
# 151   3219.491990      3041.246600   178.245390
# 122   5984.919870      5787.173850   197.746020
# 6     4104.400989      3870.299322   234.101667
# 28    2760.485982      3480.506289  -720.020307
# 71    4320.554389      4068.757614   251.796775
# 188   4385.713419      4658.485017  -272.771598
# 34    3621.261108      3399.144577   222.116531
# 21    4771.307836      4602.426114   168.881722
# 40    4363.202854      4302.061583    61.141271
# 55    4079.994302      3891.179248   188.815054
# 104   4689.432240      4996.643356  -307.211116
# 3     5098.680869      5185.023378   -86.342509
# 39    4471.241364      4124.203186   347.038178
# 117   4321.084360      4284.015707    37.068653
# ...

# %%
## step 6 prediction of unknown values
model.predict([[2, 3, 2]])
# Out:
# c:\Users\Sheharyar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([977.7367932])

# %%
# For plotting of multiple regression model
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D

# %%
# data preparation
df = pd.read_csv('unconv_MV_v5.csv')
df.head()
# Out:
#    Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0     1  12.08  2.92  2.80    81.40  1.16  2.31  4165.196191
# 1     2  12.38  3.53  3.22    46.17  0.89  1.88  3561.146205
# 2     3  14.02  2.59  4.01    72.80  0.89  2.72  4284.348574
# 3     4  17.67  6.75  2.63    39.81  1.08  1.88  5098.680869
# 4     5  17.52  4.57  3.18    10.94  1.51  1.90  3406.132832

# %%
# assigning dependent and independent variables
X = df[['Por', 'Brittle']].values.reshape(-1,2)
Y = df['Prod']

# %%
# Prepare model for data visualization
x1 = X[:, 0]
x2 = X[:, 1]
# x3 = X[:, 2]
y = Y
x1_pred = np.linspace(6, 24, 30)
x2_pred = np.linspace(0, 100, 30)
# x3_pred = np.linspace(0, 10, 30)
xx1_pred, xx2_pred = np.meshgrid(x1_pred, x2_pred)
model_viz = np.array([xx1_pred.flatten(), xx2_pred.flatten()]).T

# %%
# Training data
ols1 = linear_model.LinearRegression()
model2 = ols1.fit(X, Y)
predicted1 = model2.predict(model_viz)

# %%
# Evaluate the results/score
r2 = model2.score(X, Y)
print(r2)
# Out:
# 0.9330601183262976

# %%
plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')
# ax4 = fig.add_subplot(134, projection= '3d')

axes = [ax1, ax2, ax3]
# axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(x1, x2, y, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx1_pred.flatten(), xx2_pred.flatten(), predicted1, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('Brittle', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.text2D(0.2, 0.32, 'sheharyar', fontsize=13, ha='center', va='center',
           transform=ax1.transAxes, color='Red', alpha=0.5)
ax2.text2D(0.4, 0.42, 'sheharyar', fontsize=13, ha='center', va='center',
           transform=ax2.transAxes, color='Green', alpha=0.5)
ax3.text2D(0.85, 0.85, 'sheharyar', fontsize=13, ha='center', va='center',
           transform=ax3.transAxes, color='Black', alpha=0.5)

ax1.view_init(elev=28, azim=120)
ax2.view_init(elev=4, azim=114)
ax3.view_init(elev=60, azim=165)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()
